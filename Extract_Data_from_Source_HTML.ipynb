# %%
import requests
import urllib.request
from bs4 import BeautifulSoup
V = ""

url = "https://theinternship.io/"
response = requests.get(url)


soup = BeautifulSoup(response.text, 'html.parser')

src = []
src_sort = []
b = soup.find_all("img", attrs={"class": "center-logos"})
for i in b :
  #print(i['src'])
  src.append(i['src'])
  

data = soup.find_all("span")

des_company = []
for i in range(len(data)):
    des_company.append(data[i].text)
    #print(data[i].text)
des_company

di = {}
for i in range(len(des_company)) :
  di[des_company[i]] = src[i]

for i in sorted(di,key=len) :
  print(di[i])
  src_sort.append(di[i])
#sorted(di)
#di
# Out:
# company/beid_logo.png
# company/3ds_logo.png
# health-at-home.png
# company/zeekdoc_logo.png
# company/click_logo.png
# company/ava_logo.png
# company/golfdigg_logo.png
# company/accrevo_logo.png
# company/coursesquare_logo.png
# company/wisible_logo.png
# company/queq_logo.png
# company/codeapp_logo.png
# company/horganice_logo.png
# company/krungsri_logo.png
# company/pi-r-2_logo.png
# company/billme_logo.png
# company/sellsuki_logo.png
# company/fire-one-one_logo.png
# company/itax_logo.png
# company/rabbit_logo.png
# company/creativeme_logo.png

# %%
src_sort
# Out:
# ['company/beid_logo.png',
#  'company/3ds_logo.png',
#  'health-at-home.png',
#  'company/zeekdoc_logo.png',
#  'company/click_logo.png',
#  'company/ava_logo.png',
#  'company/golfdigg_logo.png',
#  'company/accrevo_logo.png',
#  'company/coursesquare_logo.png',
#  'company/wisible_logo.png',
#  'company/queq_logo.png',
#  'company/codeapp_logo.png',
#  'company/horganice_logo.png',
#  'company/krungsri_logo.png',
#  'company/pi-r-2_logo.png',
#  'company/billme_logo.png',
#  'company/sellsuki_logo.png',
#  'company/fire-one-one_logo.png',
#  'company/itax_logo.png',
#  'company/rabbit_logo.png',
#  'company/creativeme_logo.png']

# %%
import json
import requests

response = requests.get("https://my-json-server.typicode.com/swu60328/swu60328-repo/db")
todos = json.loads(response.text)
todos
# Out:
# {'companies': [{'logo': 'https://theinternship.io/company/beid_logo.png'},
#   {'logo': 'https://theinternship.io/company/3ds_logo.png'},
#   {'logo': 'https://theinternship.io/health-at-home.png'},
#   {'logo': 'https://theinternship.io/company/zeekdoc_logo.png'},
#   {'logo': 'https://theinternship.io/company/click_logo.png'},
#   {'logo': 'https://theinternship.io/company/ava_logo.png'},
#   {'logo': 'https://theinternship.io/company/golfdigg_logo.png'},
#   {'logo': 'https://theinternship.io/company/accrevo_logo.png'},
#   {'logo': 'https://theinternship.io/company/coursesquare_logo.png'},
#   {'logo': 'https://theinternship.io/company/wisible_logo.png'},
#   {'logo': 'https://theinternship.io/company/queq_logo.png'},
#   {'logo': 'https://theinternship.io/company/codeapp_logo.png'},
#   {'logo': 'https://theinternship.io/company/horganice_logo.png'},
#   {'logo': 'https://theinternship.io/company/krungsri_logo.png'},
# ...

# %%
import json
l = []

  
data = {  "companies" : [] }
for i in range(len(src_sort)) :
  data["companies"].append({"logo" : "https://theinternship.io/" + src_sort[i]})
json_data = json.dumps(data)
json_data
# Out:
# '{"companies": [{"logo": "https://theinternship.io/company/beid_logo.png"}, {"logo": "https://theinternship.io/company/3ds_logo.png"}, {"logo": "https://theinternship.io/health-at-home.png"}, {"logo": "https://theinternship.io/company/zeekdoc_logo.png"}, {"logo": "https://theinternship.io/company/click_logo.png"}, {"logo": "https://theinternship.io/company/ava_logo.png"}, {"logo": "https://theinternship.io/company/golfdigg_logo.png"}, {"logo": "https://theinternship.io/company/accrevo_logo.png"}, {"logo": "https://theinternship.io/company/coursesquare_logo.png"}, {"logo": "https://theinternship.io/company/wisible_logo.png"}, {"logo": "https://theinternship.io/company/queq_logo.png"}, {"logo": "https://theinternship.io/company/codeapp_logo.png"}, {"logo": "https://theinternship.io/company/horganice_logo.png"}, {"logo": "https://theinternship.io/company/krungsri_logo.png"}, {"logo": "https://theinternship.io/company/pi-r-2_logo.png"}, {"logo": "https://theinternship.io/company/billme_l
# ...

# %%
with open("test.json", "w") as write_file:
    json.dump(data, write_file)

# %%
response = requests.get("https://api.jsonbin.io/b/5e3837d150a7fe418c58e1e7")
todos = json.loads(response.text)
todos
# Out:
# {'message': 'Need to provide a secret-key to READ private bins',
#  'success': False}

# %%
url = "https://theinternship.io/"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html data-n-head="" data-n-head-ssr="">
#  <head>
#   <title data-n-head="true">
#    The Internship 2020
#   </title>
#   <meta charset="utf-8" data-n-head="true"/>
#   <meta content="width=device-width,initial-scale=1" data-n-head="true" name="viewport"/>
#   <meta content="#29211F" data-n-head="true" name="theme-color"/>
#   <meta content="The Internship 2020" data-hid="description" data-n-head="true"/>
#   <meta content="http://www.theinternship.io" data-n-head="true" property="og:url"/>
#   <meta content="The Internship Program ที่สุดของประสบการณ์ฝึกงานกับ Startup" data-n-head="true" property="og:title"/>
#   <meta content="http://www.theinternship.io/og_2020.jpg" data-n-head="true" property="og:image"/>
#   <meta content="The Internship Program โครงการที่เปิดโอกาสให้นักศึกษา ได้มีโอกาสฝึกงานกับ Tech Startup ชั้นแนวหน้าของไทย ไม่ว่าจะเป็น Developer, Designer หรือ Business เปิดรับสมัคร 14 - 31 มกราคม 2562" data-n-head="true" property="og:description"/>
# ...

# %%
#b = soup.find_all('a',attclass_ = "center-logos")
src = []
b = soup.find_all("img", attrs={"class": "center-logos"})
for i in b :
  print(i['src'])
  src.append(i['src'])
  src
#b
#images = soup.findAll('img')[10]
#print(images.get("src"))
# Out:
# company/wisible_logo.png
# company/codeapp_logo.png
# company/horganice_logo.png
# company/pi-r-2_logo.png
# company/sellsuki_logo.png
# company/billme_logo.png
# company/queq_logo.png
# company/creativeme_logo.png
# company/itax_logo.png
# company/accrevo_logo.png
# company/fire-one-one_logo.png
# company/rabbit_logo.png
# company/ava_logo.png
# company/click_logo.png
# company/krungsri_logo.png
# company/zeekdoc_logo.png
# company/golfdigg_logo.png
# health-at-home.png
# company/coursesquare_logo.png
# company/beid_logo.png
# company/3ds_logo.png
# ['company/wisible_logo.png',
#  'company/codeapp_logo.png',
#  'company/horganice_logo.png',
#  'company/pi-r-2_logo.png',
#  'company/sellsuki_logo.png',
#  'company/billme_logo.png',
#  'company/queq_logo.png',
#  'company/creativeme_logo.png',
#  'company/itax_logo.png',
#  'company/accrevo_logo.png',
#  'company/fire-one-one_logo.png',
#  'company/rabbit_logo.png',
#  'company/ava_logo.png',
#  'company/click_logo.png',
# ...

# %%
b
# Out:
# [<img alt="https://wisible.io" class="center-logos" data-v-018ba4ef="" src="company/wisible_logo.png"/>,
#  <img alt="https://www.code-app.com/" class="center-logos" data-v-018ba4ef="" src="company/codeapp_logo.png"/>,
#  <img alt="https://www.horganice.in.th/internship/" class="center-logos" data-v-018ba4ef="" src="company/horganice_logo.png"/>,
#  <img alt="http://www.pirsquare.net/" class="center-logos" data-v-018ba4ef="" src="company/pi-r-2_logo.png"/>,
#  <img alt="http://www.sellsuki.co.th/" class="center-logos" data-v-018ba4ef="" src="company/sellsuki_logo.png"/>,
#  <img alt="https://www.billme.co.th" class="center-logos" data-v-018ba4ef="" src="company/billme_logo.png"/>,
#  <img alt="http://www.queq.me" class="center-logos" data-v-018ba4ef="" src="company/queq_logo.png"/>,
#  <img alt="http://www.creativeme.co.th/" class="center-logos" data-v-018ba4ef="" src="company/creativeme_logo.png"/>,
# ...

# %%
data = soup.find_all("span")
data
# Out:
# [<span class="list-company" data-v-018ba4ef="">บริษัท ไฟว์ลูป จำกัด เป็นผู้สร้าง Wisible Sales CRM Platform เป็นบริษัทเทคโนโลยีสัญชาติไทยที่ออกแบบและพัฒนาซอฟต์แวร์ด้วยทีมงานชาวไทย 100% ด้วยความมุ่งหวังที่จะสร้างเครื่องมือการทำงานที่เหมาะสมที่สุดกับการใช้งานของผู้ประกอบการเอสเอ็มอีในประเทศไทยและภูมิภาคเอเชียตะวันออกเฉียงใต้</span>,
#  <span class="list-company" data-v-018ba4ef="">Code App ถูกก่อตั้งขึ้นมาเพื่อเป็น “สนามเด็กเล่นของคนเขียนโค้ด” ที่ coders และ geeks มาทำงานด้วยความสนุกกับการสร้างสรรค์ซอฟต์แวร์แบบใส่ใจทุกรายละเอียด ตลอด 5 ปีที่ผ่านมา ที่เราได้ช่วยลูกค้าและพาร์ทเนอร์ของเราปรับตัวเข้าสู่ยุคดิจิทัลยุคสารสนเทศ ยุคของอัลกอริทึม ... เรากำลังเปลี่ยนโลก ทีละแอปพลิเคชั่น</span>,
# ...

# %%
des_company = []
for i in range(len(data)):
    des_company.append(data[i].text)
    #print(data[i].text)
des_company
# Out:
# ['บริษัท ไฟว์ลูป จำกัด เป็นผู้สร้าง Wisible Sales CRM Platform เป็นบริษัทเทคโนโลยีสัญชาติไทยที่ออกแบบและพัฒนาซอฟต์แวร์ด้วยทีมงานชาวไทย 100% ด้วยความมุ่งหวังที่จะสร้างเครื่องมือการทำงานที่เหมาะสมที่สุดกับการใช้งานของผู้ประกอบการเอสเอ็มอีในประเทศไทยและภูมิภาคเอเชียตะวันออกเฉียงใต้',
#  'Code App ถูกก่อตั้งขึ้นมาเพื่อเป็น “สนามเด็กเล่นของคนเขียนโค้ด” ที่ coders และ geeks มาทำงานด้วยความสนุกกับการสร้างสรรค์ซอฟต์แวร์แบบใส่ใจทุกรายละเอียด ตลอด 5 ปีที่ผ่านมา ที่เราได้ช่วยลูกค้าและพาร์ทเนอร์ของเราปรับตัวเข้าสู่ยุคดิจิทัลยุคสารสนเทศ ยุคของอัลกอริทึม ... เรากำลังเปลี่ยนโลก ทีละแอปพลิเคชั่น',
#  'Horganice เป็นระบบบริหารจัดการหอพัก อพาร์ทเม้นท์ ในรูปแบบ Online มาพร้อมกับฟังก์ชันที่ครอบคลุมการบริหารหอพักตั้งแต่การวางใบแจ้งหนี้ การชำระเงิน การวิเคราะห์ผลประกอบการ และยังมีระบบเชื่อมต่อการสื่อสารกับผู้เช่า ที่จะช่วยให้เจ้าของหอพักทำงานได้ง่ายและสะดวกเป็นเสือนอนกิน และ ยกระดับการอยู่อาศัยของผู้เช่า',
# ...

# %%
di = {}
for i in range(len(des_company)) :
  di[des_company[i]] = src[i]

sorted(di)
for i in sorted(di,key=len) :
  print(di[i])

sorted(di,key=len)
# Out:
# company/beid_logo.png
# company/3ds_logo.png
# health-at-home.png
# company/zeekdoc_logo.png
# company/click_logo.png
# company/ava_logo.png
# company/golfdigg_logo.png
# company/accrevo_logo.png
# company/coursesquare_logo.png
# company/wisible_logo.png
# company/queq_logo.png
# company/codeapp_logo.png
# company/horganice_logo.png
# company/krungsri_logo.png
# company/pi-r-2_logo.png
# company/billme_logo.png
# company/sellsuki_logo.png
# company/fire-one-one_logo.png
# company/itax_logo.png
# company/rabbit_logo.png
# company/creativeme_logo.png
# ['BeID one stop service digital identity platform',
#  '3DS Interactive Data Analytics Marketing Agency',
#  'Health At Home บริการดูแลผู้สูงอายุและผู้ป่วย ส่งตรงถึงบ้านคุณ',
#  'Zeek Doc ค้นหาแพทย์ใกล้บ้านนัดหมายออนไลน์ . และระบบจัดการนัดหมายสำหรับคลินิก',
#  'King Power Click The leading Creative and Technology Enabler providing the best Innovative businesses',
# ...

# %%
des_company
des_company.sort(key=len)

# %%
des_company
# Out:
# ['BeID one stop service digital identity platform',
#  '3DS Interactive Data Analytics Marketing Agency',
#  'Health At Home บริการดูแลผู้สูงอายุและผู้ป่วย ส่งตรงถึงบ้านคุณ',
#  'Zeek Doc ค้นหาแพทย์ใกล้บ้านนัดหมายออนไลน์ . และระบบจัดการนัดหมายสำหรับคลินิก',
#  'King Power Click The leading Creative and Technology Enabler providing the best Innovative businesses',
#  'AVA is an investment Robo-Advisor with Artificial Intelligence technology to help investors increase their investment return with the ease of use.',
#  'Golf Digg Best Golf Booking Service In Thailand: Quickly and Easy Online Golf Booking Service to book tee time at over 150 great golf courses all across Thailand',
#  'AccRevo ผู้ให้บริการด้านบัญชีในโลกยุคดิจิทัล ที่จะช่วยให้ผู้ประกอบการมีความสะดวก บริหารจัดการความยุ่งยากด้านเอกสารทางบัญชีได้ง่าย ทุกที่ทุกเวลา ช่วยให้ผู้ประกอบการ รับรู้ผลประกอบการที่ถูกต้องได้เร็วขึ้น',
# ...
